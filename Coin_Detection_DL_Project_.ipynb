# %% [markdown]
# # Coin Detection with YOLOv3
# **Abhishek** **19BCI7058**
#
# **Divyansh** **19BCD7171**
#
# **Prashant Fachara** **19BCE7271**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  102_Oxford_Dataset
#  Abhishek__01.jpg
# 'Annexure - I Tentative List of Courses.gdoc'
# 'Annexure - I Tentative List of Courses.pdf'
#  AWS_Badge.PNG
#  Classroom
#  Coin_dataset
# 'Colab Notebooks'
# 'concept-learning class.ppt'
#  Dataset_Brain_MRI
# 'Decision Trees Class.PPT'
#  DL9_FaceMask
# 'Ensemble Learning and Random Forest.pptx'
#  Flowers
# 'Getting started.pdf'
#  Lab_10_UDP_Client_Server_Abhishek_19BCI7058.gdoc
# 'My Drive'
#  OOP_Lab_10_01_12_2020.19BCI7058.docx
#  OOP_Lab_1_10_11_20_19BCI7058.docx
#  OOP_Lab_12.19BCI7058.docx
#  OOP_Lab_2_19BCI7058.docx
#  OOP_LAB_3_13_11_2020_19BCI7058.pdf
#  OOP_Lab_4_17_11_20_19BCI7058.docx
#  OOP_Lab_6_20_11_2020.19BCI7058.docx
#  OOP_Lab_7_24_11_2020.19BCI7058.docx
#  OOP_Lab_8_25_11_2020.19BCI7058.docx
#  OOP_lAB_9_27_11_2020.19BCI7058.docx
#  Project_Abstract.gdoc
#  Report.gdoc
#  yolov3
#  YOLOv3

# %% [markdown]
# **1) Clone the Darknet**

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %% [markdown]
# ** Compiling  Darknet

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %% [markdown]
# **3) Configure Darknet network for training YOLO V3**

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=18@' cfg/yolov3_training.cfg

# %%
# !mkdir "/mydrive/yolov3"
# Out:
# mkdir: cannot create directory ‘/mydrive/yolov3’: File exists

# %%
# !echo "1_Lira_Turkey" > data/obj.names
# !echo -e 'classes= 1\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3' > data/obj.data
# !mkdir data/obj
# Out:
# mkdir: cannot create directory ‘data/obj’: File exists

# %%
# Downloading  weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-12-18 19:09:06--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M  56.0MB/s    in 2.8s
#
# 2021-12-18 19:09:09 (56.0 MB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %% [markdown]
# ** Extracting Images**

# %%
# !unzip /mydrive/yolov3/Lira_Turkey.zip -d data/obj
# Out:
# Archive:  /mydrive/yolov3/Lira_Turkey.zip
#   inflating: data/obj/001__1 Lira_turkey.jpg
#   inflating: data/obj/001__1 Lira_turkey.txt
#   inflating: data/obj/002__1 Lira_turkey.jpg
#   inflating: data/obj/002__1 Lira_turkey.txt
#   inflating: data/obj/003__1 Lira_turkey.jpg
#   inflating: data/obj/003__1 Lira_turkey.txt
#   inflating: data/obj/004__1 Lira_turkey.jpg
#   inflating: data/obj/004__1 Lira_turkey.txt
#   inflating: data/obj/005__1 Lira_turkey.jpg
#   inflating: data/obj/005__1 Lira_turkey.txt
#   inflating: data/obj/006__1 Lira_turkey.jpg
#   inflating: data/obj/006__1 Lira_turkey.txt
#   inflating: data/obj/007_1Lira_turkey.jpg
#   inflating: data/obj/007_1Lira_turkey.txt
#   inflating: data/obj/008_1Lira_turkey.jpg
#   inflating: data/obj/008_1Lira_turkey.txt
#   inflating: data/obj/009__1 Lira_turkey.jpg
#   inflating: data/obj/009__1 Lira_turkey.txt
#   inflating: data/obj/010__1 Lira_turkey.jpg
#   inflating: data/obj/010__1 Lira_turkey.txt
# ...

# %%
# Converting the class index on the .txt files. As we're working with only one class, it's supposed to be class 0.
# If the index is different from 0 then we're going to change it.
import glob
import os
import re

txt_file_paths = glob.glob(r"data/obj/*.txt")
for i, file_path in enumerate(txt_file_paths):
    
    with open(file_path, "r") as f_o:
        lines = f_o.readlines()

        text_converted = []
        for line in lines:
            print(line)
            numbers = re.findall("[0-9.]+", line)
            print(numbers)
            if numbers:

                # Defining  coordinates
                text = "{} {} {} {} {}".format(0, numbers[1], numbers[2], numbers[3], numbers[4])
                text_converted.append(text)
                print(i, file_path)
                print(text)
        # Write file
        with open(file_path, 'w') as fp:
            for item in text_converted:
                fp.writelines("%s\n" % item)
# Out:
# 15 0.501250 0.495645 0.430000 0.625436
#
# ['15', '0.501250', '0.495645', '0.430000', '0.625436']
# 0 data/obj/081_1Lira_turkey.txt
# 0 0.501250 0.495645 0.430000 0.625436
# 15 0.733753 0.455357 0.423480 0.753571
#
# ['15', '0.733753', '0.455357', '0.423480', '0.753571']
# 1 data/obj/011_1Lira_turkey.txt
# 0 0.733753 0.455357 0.423480 0.753571
# 15 0.519144 0.521253 0.876126 0.881432
#
# ['15', '0.519144', '0.521253', '0.876126', '0.881432']
# 2 data/obj/077_1Lira_turkey.txt
# 0 0.519144 0.521253 0.876126 0.881432
# 15 0.522629 0.515116 0.799569 0.872093
#
# ['15', '0.522629', '0.515116', '0.799569', '0.872093']
# 3 data/obj/040_1Lira_turkey.txt
# 0 0.522629 0.515116 0.799569 0.872093
# 15 0.461250 0.532833 0.375000 0.529081
#
# ['15', '0.461250', '0.532833', '0.375000', '0.529081']
# 4 data/obj/127_1Lira_turkey.txt
# 0 0.461250 0.532833 0.375000 0.529081
# 15 0.489063 0.491667 0.540625 0.927778
#
# ['15', '0.489063', '0.491667', '0.540625', '0.927778']
# ...

# %%
import glob
images_list = glob.glob("data/obj/*.jpg")
print(images_list)
# Out:
# ['data/obj/181_1Lira_turkey.jpg', 'data/obj/085_1Lira_turkey.jpg', 'data/obj/038__1 Lira_turkey.jpg', 'data/obj/160_1Lira_turkey.jpg', 'data/obj/178_1Lira_turkey.jpg', 'data/obj/192_1Lira_turkey.jpg', 'data/obj/072_1Lira_turkey.jpg', 'data/obj/153_1Lira_turkey.jpg', 'data/obj/127_1Lira_turkey.jpg', 'data/obj/110_1Lira_turkey.jpg', 'data/obj/022__1 Lira_turkey.jpg', 'data/obj/100_1Lira_turkey.jpg', 'data/obj/019_1Lira_turkey.jpg', 'data/obj/011_1Lira_turkey.jpg', 'data/obj/191_1Lira_turkey.jpg', 'data/obj/135_1Lira_turkey.jpg', 'data/obj/034__1 Lira_turkey.jpg', 'data/obj/046_1Lira_turkey.jpg', 'data/obj/183_1Lira_turkey.jpg', 'data/obj/005__1 Lira_turkey.jpg', 'data/obj/201_1Lira_turkey.jpg', 'data/obj/035__1 Lira_turkey.jpg', 'data/obj/047_Lira_turkey.jpg', 'data/obj/193_1Lira_turkey.jpg', 'data/obj/114_1Lira_turkey.jpg', 'data/obj/185_1Lira_turkey.jpg', 'data/obj/190_1Lira_turkey.jpg', 'data/obj/177_1Lira_turkey.jpg', 'data/obj/020__1 Lira_turkey.jpg', 'data/obj/007_1Lira_turkey.jp
# ...

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %% [markdown]
# ** Training **

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 52289, rewritten_bbox = 0.701868 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.670856), count: 4, class_loss = 0.581138, iou_loss = 0.320111, total_loss = 0.901250
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000011, iou_loss = 0.000000, total_loss = 0.000011
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000006, iou_loss = 0.000000, total_loss = 0.000006
#  total_bbox = 52293, rewritten_bbox = 0.701815 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.817650), count: 4, class_loss = 0.297698, iou_loss = 0.116075, total_loss = 0.413773
# ...
